# %% [markdown]
# #                        President Elections 1976 - 2016

# %%
__author__ = "Stephanie Marin V."
__copyright__ = "Copyright 2019, Stephanie Marin"
__email__ = "stephaniemarin05@yahoo.com"

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

#importing train test_split
from sklearn.model_selection import train_test_split

# %%
# Import the campaign dataset from Excel (Sheet 0 = Non Responders, Sheet 1 = Responders)
president_df = pd.read_csv("president.csv")

# %%
president_df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
#year, state, state postal code state abreviation, state FIPS code, U.S Census state code, icpsr state code,
#name of the candidate, party, writein, candidate votes, total votes

president_df.shape
# Out:
# (3740, 14)

# %% [markdown]
# <h3> Using PANDAS .loc method to display important variables </h3>

# %%
president = president_df.loc[ :, ["year", "state", "state_po", "office", "candidate", "party", "candidatevotes", "totalvotes"]]
president.head()
# Out:
#    year    state state_po        office                candidate  \
# 0  1976  Alabama       AL  US President            Carter, Jimmy
# 1  1976  Alabama       AL  US President             Ford, Gerald
# 2  1976  Alabama       AL  US President           Maddox, Lester
# 3  1976  Alabama       AL  US President  Bubar, Benjamin ""Ben""
# 4  1976  Alabama       AL  US President                Hall, Gus
#
#                         party  candidatevotes  totalvotes
# 0                    democrat          659170     1182850
# 1                  republican          504070     1182850
# 2  american independent party            9198     1182850
# 3                 prohibition            6669     1182850
# 4         communist party use            1954     1182850

# %%
president["candidate"].head()
# Out:
# 0              Carter, Jimmy
# 1               Ford, Gerald
# 2             Maddox, Lester
# 3    Bubar, Benjamin ""Ben""
# 4                  Hall, Gus
# Name: candidate, dtype: object

# %%
president["candidatevotes"].mean()
# Out:
# 315138.8631016043

# %%
president.mean()
# Out:
# year              1.996021e+03
# candidatevotes    3.151389e+05
# totalvotes        2.214284e+06
# dtype: float64

# %% [markdown]
#  Number of election years in this Database from 1976 - 2016

# %%
numelections = president.year.value_counts()
numelections.head(12)
# Out:
# 1992    370
# 2000    369
# 1996    368
# 1980    364
# 2008    351
# 2016    345
# 1976    332
# 1984    323
# 2004    317
# 2012    316
# 1988    285
# Name: year, dtype: int64

# %% [markdown]
# <h4> Populated True or False. Where true is 2016, showing the last 5 indexes. </h4>

# %%
# assigning the most recent election to lastYear where is greater than 2012

lastYear = president["year"]> 2012
lastYear
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3710     True
# 3711     True
# 3712     True
# 3713     True
# 3714     True
# 3715     True
# 3716     True
# 3717     True
# 3718     True
# 3719     True
# 3720     True
# 3721     True
# 3722     True
# 3723     True
# 3724     True
# 3725     True
# 3726     True
# 3727     True
# 3728     True
# 3729     True
# 3730     True
# 3731     True
# 3732     True
# 3733     True
# 3734     True
# 3735     True
# 3736     True
# 3737     True
# 3738     True
# 3739     True
# ...

# %% [markdown]
# <h4> Populating database with 2016 year only. The first 5 indexes. </h4>

# %%
#lastElection is now assigned to 

lastElection = president[lastYear]
lastElection
# Out:
#       year          state state_po        office  \
# 3395  2016        Alabama       AL  US President
# 3396  2016        Alabama       AL  US President
# 3397  2016        Alabama       AL  US President
# 3398  2016        Alabama       AL  US President
# 3399  2016        Alabama       AL  US President
# 3400  2016         Alaska       AK  US President
# 3401  2016         Alaska       AK  US President
# 3402  2016         Alaska       AK  US President
# 3403  2016         Alaska       AK  US President
# 3404  2016         Alaska       AK  US President
# 3405  2016         Alaska       AK  US President
# 3406  2016         Alaska       AK  US President
# 3407  2016        Arizona       AZ  US President
# 3408  2016        Arizona       AZ  US President
# 3409  2016        Arizona       AZ  US President
# 3410  2016        Arizona       AZ  US President
# 3411  2016        Arizona       AZ  US President
# 3412  2016        Arizona       AZ  US President
# ...

# %%
#filtering candidates' name to Donal J. Trump the firs 5 indexes

candidate_Trump = (president["candidate"] == "Trump, Donald J.") & (president["year"] > 2012)
filter_candidate_Trump = president [candidate_Trump]
filter_candidate_Trump.head()
# Out:
#       year       state state_po        office         candidate       party  \
# 3395  2016     Alabama       AL  US President  Trump, Donald J.  republican
# 3400  2016      Alaska       AK  US President  Trump, Donald J.  republican
# 3407  2016     Arizona       AZ  US President  Trump, Donald J.  republican
# 3417  2016    Arkansas       AR  US President  Trump, Donald J.  republican
# 3426  2016  California       CA  US President  Trump, Donald J.  republican
#
#       candidatevotes  totalvotes
# 3395         1318255     2123372
# 3400          163387      318608
# 3407         1252401     2573165
# 3417          684872     1130635
# 3426         4483810    14181595

# %%
#filtering candidates' name to Hillary Clinton the firs 5 indexes

candidate_Clinton = (president["candidate"] == "Clinton, Hillary") & ( president["year"] > 2012 )
filter_candidate_Clinton = president[candidate_Clinton]
filter_candidate_Clinton.head()
# Out:
#       year       state state_po        office         candidate     party  \
# 3396  2016     Alabama       AL  US President  Clinton, Hillary  democrat
# 3401  2016      Alaska       AK  US President  Clinton, Hillary  democrat
# 3408  2016     Arizona       AZ  US President  Clinton, Hillary  democrat
# 3418  2016    Arkansas       AR  US President  Clinton, Hillary  democrat
# 3425  2016  California       CA  US President  Clinton, Hillary  democrat
#
#       candidatevotes  totalvotes
# 3396          729547     2123372
# 3401          116454      318608
# 3408         1161167     2573165
# 3418          380494     1130635
# 3425         8753788    14181595

# %%
filter_candidate_Clinton.loc[:, ["state","candidate", "candidatevotes"]]
# Out:
#                      state         candidate  candidatevotes
# 3396               Alabama  Clinton, Hillary          729547
# 3401                Alaska  Clinton, Hillary          116454
# 3408               Arizona  Clinton, Hillary         1161167
# 3418              Arkansas  Clinton, Hillary          380494
# 3425            California  Clinton, Hillary         8753788
# 3431              Colorado  Clinton, Hillary         1338870
# 3451           Connecticut  Clinton, Hillary          897572
# 3456              Delaware  Clinton, Hillary          235603
# 3460  District of Columbia  Clinton, Hillary          282830
# 3468               Florida  Clinton, Hillary         4504975
# 3475               Georgia  Clinton, Hillary         1877963
# 3478                Hawaii  Clinton, Hillary          266891
# 3486                 Idaho  Clinton, Hillary          189765
# 3490              Illinois  Clinton, Hillary         3090729
# ...

# %%
filter_candidate_Trump.loc[:, ["state","candidate", "candidatevotes"]]
# Out:
#                      state         candidate  candidatevotes
# 3395               Alabama  Trump, Donald J.         1318255
# 3400                Alaska  Trump, Donald J.          163387
# 3407               Arizona  Trump, Donald J.         1252401
# 3417              Arkansas  Trump, Donald J.          684872
# 3426            California  Trump, Donald J.         4483810
# 3432              Colorado  Trump, Donald J.         1202484
# 3452           Connecticut  Trump, Donald J.          673215
# 3457              Delaware  Trump, Donald J.          185127
# 3461  District of Columbia  Trump, Donald J.           12723
# 3467               Florida  Trump, Donald J.         4617886
# 3474               Georgia  Trump, Donald J.         2089104
# 3479                Hawaii  Trump, Donald J.          128847
# 3485                 Idaho  Trump, Donald J.          409055
# 3491              Illinois  Trump, Donald J.         2146015
# ...
